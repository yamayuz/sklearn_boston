# %% [markdown]
# # Deep Learningによるボストンの住宅価格予測

# %% [markdown]
# ## 住宅価格データの読み込みと表示

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()
features = boston.data
feature_names = boston.feature_names
targets = boston.target
